# %% [markdown]
# <a href="https://colab.research.google.com/github/agabuzova/test1/blob/main/Gabuzova_R_homework3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3.2.4 Exercises

# %%
install.packages("tidyverse")
library(tidyverse)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
#Run ggplot(data = mpg). What do you see?
ggplot(data = mpg)
#ничего нет
# Out:
# plot without title

# %%
#How many rows are in mpg?
nrow(mpg)
#количество строк
# Out:
# [1] 234

# %%
#How many columns?
ncol(mpg)
#количество столбцов
# Out:
# [1] 11

# %%
#What does the drv variable describe? Read the help for ?mpg to find out.
#Drv - the type of drive train, where f = front-wheel drive, r= rear wheel drive, 4=wd

# %%
#Make a scatterplot of hwy vs cyl
ggplot(mpg, aes(x = cyl, y = hwy)) +
  geom_point()
# Out:
# plot without title

# %%
#What happens if you make a scatterplot of class vs drv? Why is the plot not useful?
ggplot(mpg, aes(x = class, y = drv)) +
  geom_point()

#потому что ничего не понятно по картинке, никакой зависимости не видно.
# Out:
# plot without title

# %%
#3.3.1 Exercises
#What’s gone wrong with this code? Why are the points not blue?

ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy, colour = "blue"))
  #нужно указывать цвет после скобок aes()
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy), colour = "blue")
# Out:
# plot without title

# %% [markdown]
# Which variables in mpg are categorical? Which variables are continuous?
# (Hint: type ?mpg to read the documentation for the dataset). How can you see this information when you run mpg?

# %%
#тип переменных показывает функция ниже
glimpse(mpg)
# Out:
# Rows: 234
# Columns: 11
# $ manufacturer <chr> "audi", "audi", "audi", "audi", "audi", "audi", "audi", "…
# $ model        <chr> "a4", "a4", "a4", "a4", "a4", "a4", "a4", "a4 quattro", "…
# $ displ        <dbl> 1.8, 1.8, 2.0, 2.0, 2.8, 2.8, 3.1, 1.8, 1.8, 2.0, 2.0, 2.…
# $ year         <int> 1999, 1999, 2008, 2008, 1999, 1999, 2008, 1999, 1999, 200…
# $ cyl          <int> 4, 4, 4, 4, 6, 6, 6, 4, 4, 4, 4, 6, 6, 6, 6, 6, 6, 8, 8, …
# $ trans        <chr> "auto(l5)", "manual(m5)", "manual(m6)", "auto(av)", "auto…
# $ drv          <chr> "f", "f", "f", "f", "f", "f", "f", "4", "4", "4", "4", "4…
# $ cty          <int> 18, 21, 20, 21, 16, 18, 18, 18, 16, 20, 19, 15, 17, 17, 1…
# $ hwy          <int> 29, 29, 31, 30, 26, 26, 27, 26, 25, 28, 27, 25, 25, 25, 2…
# $ fl           <chr> "p", "p", "p", "p", "p", "p", "p", "p", "p", "p", "p", "p…
# $ class        <chr> "compact", "compact", "compact", "compact", "compact", "c…

# %% [markdown]
# Map a continuous variable to color, size, and shape. How do these aesthetics behave differently for categorical vs. continuous variables?

# %%
ggplot(mpg, aes(x = displ, y = hwy, colour = cty)) +
  geom_point()
# Out:
# plot without title

# %%
ggplot(mpg, aes(x = displ, y = hwy, size = cty)) +
  geom_point()
# Out:
# plot without title

# %%
#What happens if you map the same variable to multiple aesthetics?
ggplot(mpg, aes(x = displ, y = hwy, colour = hwy, size = displ)) +
  geom_point()

#в этом нет смысла, нерепрезентативно
# Out:
# plot without title

# %%
#What does the stroke aesthetic do? What shapes does it work with? (Hint: use ?geom_point)
#меняет размер границ фигур

# %% [markdown]
# What happens if you map an aesthetic to something other than a variable name, like aes(colour = displ < 5)? Note, you’ll also need to specify x and y.

# %%
ggplot(mpg, aes(x = displ, y = hwy, colour = displ < 5)) +
  geom_point()

#цвет меняется в зависимости от результата логического выражения displ < 5
# Out:
# plot without title
